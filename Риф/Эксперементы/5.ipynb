# %%
experements = []
arr_algo = []

for i in range(10):
    RANDOM_SEED = i
    random.seed(RANDOM_SEED)
    np.random.seed(RANDOM_SEED)
    algo = GA(100, 0.9, 0.1, 100)
    algo.optimize()
    arr_algo.append(algo)
    experements.append(algo.HISTORY)
    algo.print_res()
    print()
# Out:
# Cвертка: 6.51312815279783e-05,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 3, 0], '50': [5, 4, 1, 0], '60': [6, 3, 0], '70': [7, 4, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 300, '03': 400, '12': 100, '14': 100, '25': 0, '34': 200, '36': 100, '45': 100, '47': 100, '67': 0}
# v_reseive_to_node: [700, 200, 0, 300, 200, 0, 0, 0]
# v_sent_to_node: [0, 300, 100, 400, 300, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 25.0, 5.0, 35.0, 25.0, 5.0, 5.0, 5.0]
# t_edges: [15.0, 20.0, 5.0, 5.0, 0.0, 10.0, 5.0, 5.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Ограничения
# 1
#
#
#
# Cвертка: 6.51312815279783e-05,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 1, 0], '50': [5, 2, 1, 0], '60': [6, 3, 0], '70': [7, 6, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 400, '03': 300, '12': 200, '14': 100, '25': 100, '34': 0, '36': 200, '45': 0, '47': 0, '67': 100}
# v_reseive_to_node: [700, 300, 100, 200, 0, 0, 100, 0]
# v_sent_to_node: [0, 400, 200, 300, 100, 100, 200, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 35.0, 15.0, 25.0, 5.0, 5.0, 15.0, 5.0]
# t_edges: [20.0, 15.0, 10.0, 5.0, 5.0, 0.0, 10.0, 0.0, 0.0, 5.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Ограничения
# 1
#
#
#
# Cвертка: 6.51312815279783e-05,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 3, 0], '50': [5, 4, 3, 0], '60': [6, 3, 0], '70': [7, 4, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 200, '03': 500, '12': 100, '14': 0, '25': 0, '34': 300, '36': 100, '45': 100, '47': 100, '67': 0}
# v_reseive_to_node: [700, 100, 0, 400, 200, 0, 0, 0]
# v_sent_to_node: [0, 200, 100, 500, 300, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 15.0, 5.0, 45.0, 25.0, 5.0, 5.0, 5.0]
# t_edges: [10.0, 25.0, 5.0, 0.0, 0.0, 15.0, 5.0, 5.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Ограничения
# 1
#
#
#
# Cвертка: 6.51312815279783e-05,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 1, 0], '50': [5, 2, 1, 0], '60': [6, 3, 0], '70': [7, 4, 1, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 500, '03': 200, '12': 200, '14': 200, '25': 100, '34': 0, '36': 100, '45': 0, '47': 100, '67': 0}
# v_reseive_to_node: [700, 400, 100, 100, 100, 0, 0, 0]
# v_sent_to_node: [0, 500, 200, 200, 200, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 45.0, 15.0, 15.0, 15.0, 5.0, 5.0, 5.0]
# t_edges: [25.0, 10.0, 10.0, 10.0, 5.0, 0.0, 5.0, 0.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Ограничения
# 1
#
#
#
# Cвертка: 6.51312815279783e-05,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 3, 0], '50': [5, 4, 1, 0], '60': [6, 3, 0], '70': [7, 4, 1, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 400, '03': 300, '12': 100, '14': 200, '25': 0, '34': 100, '36': 100, '45': 100, '47': 100, '67': 0}
# v_reseive_to_node: [700, 300, 0, 200, 200, 0, 0, 0]
# v_sent_to_node: [0, 400, 100, 300, 300, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 35.0, 5.0, 25.0, 25.0, 5.0, 5.0, 5.0]
# t_edges: [20.0, 15.0, 5.0, 10.0, 0.0, 5.0, 5.0, 5.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Ограничения
# 1
#
#
#
# Cвертка: 6.51312815279783e-05,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 1, 0], '50': [5, 4, 1, 0], '60': [6, 3, 0], '70': [7, 4, 1, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 500, '03': 200, '12': 100, '14': 300, '25': 0, '34': 0, '36': 100, '45': 100, '47': 100, '67': 0}
# v_reseive_to_node: [700, 400, 0, 100, 200, 0, 0, 0]
# v_sent_to_node: [0, 500, 100, 200, 300, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 45.0, 5.0, 15.0, 25.0, 5.0, 5.0, 5.0]
# t_edges: [25.0, 10.0, 5.0, 15.0, 0.0, 0.0, 5.0, 5.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Ограничения
# 1
#
#
#
# Cвертка: 6.51312815279783e-05,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 1, 0], '50': [5, 4, 1, 0], '60': [6, 3, 0], '70': [7, 4, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 400, '03': 300, '12': 100, '14': 200, '25': 0, '34': 100, '36': 100, '45': 100, '47': 100, '67': 0}
# v_reseive_to_node: [700, 300, 0, 200, 200, 0, 0, 0]
# v_sent_to_node: [0, 400, 100, 300, 300, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 35.0, 5.0, 25.0, 25.0, 5.0, 5.0, 5.0]
# t_edges: [20.0, 15.0, 5.0, 10.0, 0.0, 5.0, 5.0, 5.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Ограничения
# 1
#
#
#
# Cвертка: 6.51312815279783e-05,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 3, 0], '50': [5, 2, 1, 0], '60': [6, 3, 0], '70': [7, 6, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 300, '03': 400, '12': 200, '14': 0, '25': 100, '34': 100, '36': 200, '45': 0, '47': 0, '67': 100}
# v_reseive_to_node: [700, 200, 100, 300, 0, 0, 100, 0]
# v_sent_to_node: [0, 300, 200, 400, 100, 100, 200, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 25.0, 15.0, 35.0, 5.0, 5.0, 15.0, 5.0]
# t_edges: [15.0, 20.0, 10.0, 0.0, 5.0, 5.0, 10.0, 0.0, 0.0, 5.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Ограничения
# 1
#
#
#
# Cвертка: 6.51312815279783e-05,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 3, 0], '50': [5, 2, 1, 0], '60': [6, 3, 0], '70': [7, 6, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 300, '03': 400, '12': 200, '14': 0, '25': 100, '34': 100, '36': 200, '45': 0, '47': 0, '67': 100}
# v_reseive_to_node: [700, 200, 100, 300, 0, 0, 100, 0]
# v_sent_to_node: [0, 300, 200, 400, 100, 100, 200, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 25.0, 15.0, 35.0, 5.0, 5.0, 15.0, 5.0]
# t_edges: [15.0, 20.0, 10.0, 0.0, 5.0, 5.0, 10.0, 0.0, 0.0, 5.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Ограничения
# 1
#
#
#
# Cвертка: 6.51312815279783e-05,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 1, 0], '50': [5, 4, 3, 0], '60': [6, 3, 0], '70': [7, 6, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 300, '03': 400, '12': 100, '14': 100, '25': 0, '34': 100, '36': 200, '45': 100, '47': 0, '67': 100}
# v_reseive_to_node: [700, 200, 0, 300, 100, 0, 100, 0]
# v_sent_to_node: [0, 300, 100, 400, 200, 100, 200, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 25.0, 5.0, 35.0, 15.0, 5.0, 15.0, 5.0]
# t_edges: [15.0, 20.0, 5.0, 5.0, 0.0, 5.0, 10.0, 5.0, 0.0, 5.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Ограничения
# 1

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')


plt.figure(figsize = (12, 8))
for exp in range(len(experements)):
  plt.plot([i for i in range(len(experements[exp]))], np.log([getattr(experements[exp][i][-1], 'Свертка') for i in range(len(experements[exp]))]), label = str(exp))

plt.xlabel('Поколение')
plt.ylabel('Ln от свертки')
plt.legend()
plt.show()
# Out:
# <ipython-input-20-3d584a83d833>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %%
plt.figure(figsize = (12, 8))
y = np.zeros(len(experements[exp]))
for exp in range(len(experements)):
  y += np.log([getattr(experements[exp][i][-1], 'Свертка') for i in range(len(experements[exp]))])

plt.plot([i for i in range(len(experements[exp]))], y/10)

plt.xlabel('Поколение')
plt.ylabel('Avg Ln от свертки')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
experements[0][-1][-1].draw_result()

# %%
print(experements[0][-1][-1])
# Out:
# Cвертка: 6.51312815279783e-05,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 3, 0], '50': [5, 2, 1, 0], '60': [6, 3, 0], '70': [7, 4, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 300, '03': 400, '12': 200, '14': 0, '25': 100, '34': 200, '36': 100, '45': 0, '47': 100, '67': 0}
# v_reseive_to_node: [700, 200, 100, 300, 100, 0, 0, 0]
# v_sent_to_node: [0, 300, 200, 400, 200, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 25.0, 15.0, 35.0, 15.0, 5.0, 5.0, 5.0]
# t_edges: [15.0, 20.0, 10.0, 0.0, 5.0, 10.0, 5.0, 0.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Ограничения
# 1

# %%
CRITERIA = {
    'all/group':{
        # 'Название':[функция, 'min'/'max', [index_node:узлы на которые вешаем критерий, {дополнительные параметры}]]
        # 'Временя выполнение задачи (с)' :[f1, 'min', {'index_node':[i for i in range(net.number)],}],
        # 'Энергопотребление (МВт)' : [f2, 'min', {'index_node':[i for i in range(net.number)]}],
        'Объемы передаваемой информации' : [f3, 'min', {'index_node':[i for i in range(net.number)]}],
    },
    'mashin': {
        # 'Название'{
        #     index_node: [узлы на которые вешаем критерий]
        #     'f':[функция, 'min'/'max', {дополнительные параметры}]]
        # }
        #'Нагрузка':{
        #    'index_node': [i for i in range(net.number)],
        #    'f': [f4, 'min', {}]
        #},
        #'Объемы передаваемой информации': {
        #    'index_node': [i for i in range(net.number)],
        #    'f':[f5, 'min', {}]
        #},
    }
}
LIMITATIONS = {
    'all/group':{
        # 'Название':[функция, 'min'/'max', [index_node:узлы на которые вешаем критерий, {дополнительные параметры}]]
        # 'Ограничение по времени' :[f1, {'index_node':[i for i in range(net.number)], 'T_lim': 77}],
    },
    'mashin': {
        # 'Название'{
        #     index_node: [узлы на которые вешаем критерий]
        #     'f':[функция, 'min'/'max', {дополнительные параметры}]]
        # }
    }

}

# %%
Solution._NET = net
Solution._TASK = task
Solution._CRITERIA = CRITERIA
Solution._LIMITATIONS = LIMITATIONS

# %%
experements = []
arr_algo = []

for i in range(10):
    RANDOM_SEED = i
    random.seed(RANDOM_SEED)
    np.random.seed(RANDOM_SEED)
    algo = GA(100, 0.9, 0.1, 100)
    algo.optimize()
    arr_algo.append(algo)
    experements.append(algo.HISTORY)
    algo.print_res()
    print()
# Out:
# Cвертка: 0.0007142857142857143,
# Временя выполнение задачи (с): 891.34,
# Хромосома: [2 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 3, 0], '50': [5, 4, 1, 0], '60': [6, 3, 0], '70': [7, 4, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 300, '03': 400, '12': 100, '14': 100, '25': 0, '34': 200, '36': 100, '45': 100, '47': 100, '67': 0}
# v_reseive_to_node: [14000, 200, 0, 300, 200, 0, 0, 0]
# v_sent_to_node: [0, 300, 100, 400, 300, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [700.0, 25.0, 5.0, 35.0, 25.0, 5.0, 5.0, 5.0]
# t_edges: [15.0, 20.0, 5.0, 5.0, 0.0, 10.0, 5.0, 5.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Объемы передаваемой информации / min:1400
# Ограничения
# 1
#
#
#
# Cвертка: 0.0007142857142857143,
# Временя выполнение задачи (с): 296.34000000000003,
# Хромосома: [5 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 1, 0], '50': [5, 2, 1, 0], '60': [6, 3, 0], '70': [7, 6, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 400, '03': 300, '12': 200, '14': 100, '25': 100, '34': 0, '36': 200, '45': 0, '47': 0, '67': 100}
# v_reseive_to_node: [2100, 300, 100, 200, 0, 0, 100, 0]
# v_sent_to_node: [0, 400, 200, 300, 100, 100, 200, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [105.0, 35.0, 15.0, 25.0, 5.0, 5.0, 15.0, 5.0]
# t_edges: [20.0, 15.0, 10.0, 5.0, 5.0, 0.0, 10.0, 0.0, 0.0, 5.0]
#
# Целевые функции (критерии оценки)
# Объемы передаваемой информации / min:1400
# Ограничения
# 1
#
#
#
# Cвертка: 0.0007142857142857143,
# Временя выполнение задачи (с): 1241.34,
# Хромосома: [1 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 3, 0], '50': [5, 4, 3, 0], '60': [6, 3, 0], '70': [7, 4, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 200, '03': 500, '12': 100, '14': 0, '25': 0, '34': 300, '36': 100, '45': 100, '47': 100, '67': 0}
# v_reseive_to_node: [21000, 100, 0, 400, 200, 0, 0, 0]
# v_sent_to_node: [0, 200, 100, 500, 300, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [1050.0, 15.0, 5.0, 45.0, 25.0, 5.0, 5.0, 5.0]
# t_edges: [10.0, 25.0, 5.0, 0.0, 0.0, 15.0, 5.0, 5.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Объемы передаваемой информации / min:1400
# Ограничения
# 1
#
#
#
# Cвертка: 0.0007142857142857143,
# Временя выполнение задачи (с): 1241.34,
# Хромосома: [1 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 1, 0], '50': [5, 2, 1, 0], '60': [6, 3, 0], '70': [7, 4, 1, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 500, '03': 200, '12': 200, '14': 200, '25': 100, '34': 0, '36': 100, '45': 0, '47': 100, '67': 0}
# v_reseive_to_node: [21000, 400, 100, 100, 100, 0, 0, 0]
# v_sent_to_node: [0, 500, 200, 200, 200, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [1050.0, 45.0, 15.0, 15.0, 15.0, 5.0, 5.0, 5.0]
# t_edges: [25.0, 10.0, 10.0, 10.0, 5.0, 0.0, 5.0, 0.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Объемы передаваемой информации / min:1400
# Ограничения
# 1
#
#
#
# Cвертка: 0.0007142857142857143,
# Временя выполнение задачи (с): 1241.34,
# Хромосома: [1 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 3, 0], '50': [5, 4, 1, 0], '60': [6, 3, 0], '70': [7, 4, 1, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 400, '03': 300, '12': 100, '14': 200, '25': 0, '34': 100, '36': 100, '45': 100, '47': 100, '67': 0}
# v_reseive_to_node: [21000, 300, 0, 200, 200, 0, 0, 0]
# v_sent_to_node: [0, 400, 100, 300, 300, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [1050.0, 35.0, 5.0, 25.0, 25.0, 5.0, 5.0, 5.0]
# t_edges: [20.0, 15.0, 5.0, 10.0, 0.0, 5.0, 5.0, 5.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Объемы передаваемой информации / min:1400
# Ограничения
# 1
#
#
#
# Cвертка: 0.0007142857142857143,
# Временя выполнение задачи (с): 541.34,
# Хромосома: [3 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 1, 0], '50': [5, 4, 1, 0], '60': [6, 3, 0], '70': [7, 4, 1, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 500, '03': 200, '12': 100, '14': 300, '25': 0, '34': 0, '36': 100, '45': 100, '47': 100, '67': 0}
# v_reseive_to_node: [7000, 400, 0, 100, 200, 0, 0, 0]
# v_sent_to_node: [0, 500, 100, 200, 300, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [350.0, 45.0, 5.0, 15.0, 25.0, 5.0, 5.0, 5.0]
# t_edges: [25.0, 10.0, 5.0, 15.0, 0.0, 0.0, 5.0, 5.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Объемы передаваемой информации / min:1400
# Ограничения
# 1
#
#
#
# Cвертка: 0.0007142857142857143,
# Временя выполнение задачи (с): 1416.34,
# Хромосома: [0 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 1, 0], '50': [5, 4, 1, 0], '60': [6, 3, 0], '70': [7, 4, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 400, '03': 300, '12': 100, '14': 200, '25': 0, '34': 100, '36': 100, '45': 100, '47': 100, '67': 0}
# v_reseive_to_node: [24500, 300, 0, 200, 200, 0, 0, 0]
# v_sent_to_node: [0, 400, 100, 300, 300, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [1225.0, 35.0, 5.0, 25.0, 25.0, 5.0, 5.0, 5.0]
# t_edges: [20.0, 15.0, 5.0, 10.0, 0.0, 5.0, 5.0, 5.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Объемы передаваемой информации / min:1400
# Ограничения
# 1
#
#
#
# Cвертка: 0.0007142857142857143,
# Временя выполнение задачи (с): 296.34000000000003,
# Хромосома: [5 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 3, 0], '50': [5, 2, 1, 0], '60': [6, 3, 0], '70': [7, 6, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 300, '03': 400, '12': 200, '14': 0, '25': 100, '34': 100, '36': 200, '45': 0, '47': 0, '67': 100}
# v_reseive_to_node: [2100, 200, 100, 300, 0, 0, 100, 0]
# v_sent_to_node: [0, 300, 200, 400, 100, 100, 200, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [105.0, 25.0, 15.0, 35.0, 5.0, 5.0, 15.0, 5.0]
# t_edges: [15.0, 20.0, 10.0, 0.0, 5.0, 5.0, 10.0, 0.0, 0.0, 5.0]
#
# Целевые функции (критерии оценки)
# Объемы передаваемой информации / min:1400
# Ограничения
# 1
#
#
#
# Cвертка: 0.0007142857142857143,
# Временя выполнение задачи (с): 1416.34,
# Хромосома: [0 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 3, 0], '50': [5, 2, 1, 0], '60': [6, 3, 0], '70': [7, 6, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 300, '03': 400, '12': 200, '14': 0, '25': 100, '34': 100, '36': 200, '45': 0, '47': 0, '67': 100}
# v_reseive_to_node: [24500, 200, 100, 300, 0, 0, 100, 0]
# v_sent_to_node: [0, 300, 200, 400, 100, 100, 200, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [1225.0, 25.0, 15.0, 35.0, 5.0, 5.0, 15.0, 5.0]
# t_edges: [15.0, 20.0, 10.0, 0.0, 5.0, 5.0, 10.0, 0.0, 0.0, 5.0]
#
# Целевые функции (критерии оценки)
# Объемы передаваемой информации / min:1400
# Ограничения
# 1
#
#
#
# Cвертка: 0.0007142857142857143,
# Временя выполнение задачи (с): 1241.34,
# Хромосома: [1 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 1, 0], '50': [5, 4, 3, 0], '60': [6, 3, 0], '70': [7, 6, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 300, '03': 400, '12': 100, '14': 100, '25': 0, '34': 100, '36': 200, '45': 100, '47': 0, '67': 100}
# v_reseive_to_node: [21000, 200, 0, 300, 100, 0, 100, 0]
# v_sent_to_node: [0, 300, 100, 400, 200, 100, 200, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [1050.0, 25.0, 5.0, 35.0, 15.0, 5.0, 15.0, 5.0]
# t_edges: [15.0, 20.0, 5.0, 5.0, 0.0, 5.0, 10.0, 5.0, 0.0, 5.0]
#
# Целевые функции (критерии оценки)
# Объемы передаваемой информации / min:1400
# Ограничения
# 1

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')


plt.figure(figsize = (12, 8))
for exp in range(len(experements)):
  plt.plot([i for i in range(len(experements[exp]))], np.log([getattr(experements[exp][i][-1], 'Свертка') for i in range(len(experements[exp]))]), label = str(exp))

plt.xlabel('Поколение')
plt.ylabel('Ln от свертки')
plt.legend()
plt.show()
# Out:
# <ipython-input-27-3d584a83d833>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %%
plt.figure(figsize = (12, 8))
y = np.zeros(len(experements[exp]))
for exp in range(len(experements)):
  y += np.log([getattr(experements[exp][i][-1], 'Свертка') for i in range(len(experements[exp]))])

plt.plot([i for i in range(len(experements[exp]))], y/10)

plt.xlabel('Поколение')
plt.ylabel('Avg Ln от свертки')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
experements[0][-1][-1].draw_result()

# %%
print(experements[0][-1][-1])
# Out:
# Cвертка: 0.0007142857142857143,
# Временя выполнение задачи (с): 296.34000000000003,
# Хромосома: [5 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 1, 0], '50': [5, 4, 1, 0], '60': [6, 3, 0], '70': [7, 4, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 400, '03': 300, '12': 100, '14': 200, '25': 0, '34': 100, '36': 100, '45': 100, '47': 100, '67': 0}
# v_reseive_to_node: [2100, 300, 0, 200, 200, 0, 0, 0]
# v_sent_to_node: [0, 400, 100, 300, 300, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [105.0, 35.0, 5.0, 25.0, 25.0, 5.0, 5.0, 5.0]
# t_edges: [20.0, 15.0, 5.0, 10.0, 0.0, 5.0, 5.0, 5.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Объемы передаваемой информации / min:1400
# Ограничения
# 1

# %%
CRITERIA = {
    'all/group':{
        # 'Название':[функция, 'min'/'max', [index_node:узлы на которые вешаем критерий, {дополнительные параметры}]]
        # 'Временя выполнение задачи (с)' :[f1, 'min', {'index_node':[i for i in range(net.number)],}],
        'Энергопотребление (МВт)' : [f2, 'min', {'index_node':[i for i in range(net.number)]}],
        'Объемы передаваемой информации' : [f3, 'min', {'index_node':[i for i in range(net.number)]}],
    },
    'mashin': {
        # 'Название'{
        #     index_node: [узлы на которые вешаем критерий]
        #     'f':[функция, 'min'/'max', {дополнительные параметры}]]
        # }
        #'Нагрузка':{
        #    'index_node': [i for i in range(net.number)],
        #    'f': [f4, 'min', {}]
        #},
        #'Объемы передаваемой информации': {
        #    'index_node': [i for i in range(net.number)],
        #    'f':[f5, 'min', {}]
        #},
    }
}
LIMITATIONS = {
    'all/group':{
        # 'Название':[функция, 'min'/'max', [index_node:узлы на которые вешаем критерий, {дополнительные параметры}]]
        # 'Ограничение по времени' :[f1, {'index_node':[i for i in range(net.number)], 'T_lim': 77}],
    },
    'mashin': {
        # 'Название'{
        #     index_node: [узлы на которые вешаем критерий]
        #     'f':[функция, 'min'/'max', {дополнительные параметры}]]
        # }
    }

}

# %%
Solution._NET = net
Solution._TASK = task
Solution._CRITERIA = CRITERIA
Solution._LIMITATIONS = LIMITATIONS

# %%
experements = []
arr_algo = []

for i in range(10):
    RANDOM_SEED = i
    random.seed(RANDOM_SEED)
    np.random.seed(RANDOM_SEED)
    algo = GA(100, 0.9, 0.1, 100)
    algo.optimize()
    arr_algo.append(algo)
    experements.append(algo.HISTORY)
    algo.print_res()
    print()
# Out:
# Cвертка: 4.6522343948555926e-08,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 3, 0], '50': [5, 4, 1, 0], '60': [6, 3, 0], '70': [7, 4, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 300, '03': 400, '12': 100, '14': 100, '25': 0, '34': 200, '36': 100, '45': 100, '47': 100, '67': 0}
# v_reseive_to_node: [700, 200, 0, 300, 200, 0, 0, 0]
# v_sent_to_node: [0, 300, 100, 400, 300, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 25.0, 5.0, 35.0, 25.0, 5.0, 5.0, 5.0]
# t_edges: [15.0, 20.0, 5.0, 5.0, 0.0, 10.0, 5.0, 5.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Объемы передаваемой информации / min:1400
# Ограничения
# 1
#
#
#
# Cвертка: 4.6522343948555926e-08,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 1, 0], '50': [5, 2, 1, 0], '60': [6, 3, 0], '70': [7, 6, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 400, '03': 300, '12': 200, '14': 100, '25': 100, '34': 0, '36': 200, '45': 0, '47': 0, '67': 100}
# v_reseive_to_node: [700, 300, 100, 200, 0, 0, 100, 0]
# v_sent_to_node: [0, 400, 200, 300, 100, 100, 200, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 35.0, 15.0, 25.0, 5.0, 5.0, 15.0, 5.0]
# t_edges: [20.0, 15.0, 10.0, 5.0, 5.0, 0.0, 10.0, 0.0, 0.0, 5.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Объемы передаваемой информации / min:1400
# Ограничения
# 1
#
#
#
# Cвертка: 4.6522343948555926e-08,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 3, 0], '50': [5, 4, 3, 0], '60': [6, 3, 0], '70': [7, 4, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 200, '03': 500, '12': 100, '14': 0, '25': 0, '34': 300, '36': 100, '45': 100, '47': 100, '67': 0}
# v_reseive_to_node: [700, 100, 0, 400, 200, 0, 0, 0]
# v_sent_to_node: [0, 200, 100, 500, 300, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 15.0, 5.0, 45.0, 25.0, 5.0, 5.0, 5.0]
# t_edges: [10.0, 25.0, 5.0, 0.0, 0.0, 15.0, 5.0, 5.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Объемы передаваемой информации / min:1400
# Ограничения
# 1
#
#
#
# Cвертка: 4.6522343948555926e-08,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 1, 0], '50': [5, 2, 1, 0], '60': [6, 3, 0], '70': [7, 4, 1, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 500, '03': 200, '12': 200, '14': 200, '25': 100, '34': 0, '36': 100, '45': 0, '47': 100, '67': 0}
# v_reseive_to_node: [700, 400, 100, 100, 100, 0, 0, 0]
# v_sent_to_node: [0, 500, 200, 200, 200, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 45.0, 15.0, 15.0, 15.0, 5.0, 5.0, 5.0]
# t_edges: [25.0, 10.0, 10.0, 10.0, 5.0, 0.0, 5.0, 0.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Объемы передаваемой информации / min:1400
# Ограничения
# 1
#
#
#
# Cвертка: 4.6522343948555926e-08,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 3, 0], '50': [5, 4, 1, 0], '60': [6, 3, 0], '70': [7, 4, 1, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 400, '03': 300, '12': 100, '14': 200, '25': 0, '34': 100, '36': 100, '45': 100, '47': 100, '67': 0}
# v_reseive_to_node: [700, 300, 0, 200, 200, 0, 0, 0]
# v_sent_to_node: [0, 400, 100, 300, 300, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 35.0, 5.0, 25.0, 25.0, 5.0, 5.0, 5.0]
# t_edges: [20.0, 15.0, 5.0, 10.0, 0.0, 5.0, 5.0, 5.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Объемы передаваемой информации / min:1400
# Ограничения
# 1
#
#
#
# Cвертка: 4.6522343948555926e-08,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 1, 0], '50': [5, 4, 1, 0], '60': [6, 3, 0], '70': [7, 4, 1, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 500, '03': 200, '12': 100, '14': 300, '25': 0, '34': 0, '36': 100, '45': 100, '47': 100, '67': 0}
# v_reseive_to_node: [700, 400, 0, 100, 200, 0, 0, 0]
# v_sent_to_node: [0, 500, 100, 200, 300, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 45.0, 5.0, 15.0, 25.0, 5.0, 5.0, 5.0]
# t_edges: [25.0, 10.0, 5.0, 15.0, 0.0, 0.0, 5.0, 5.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Объемы передаваемой информации / min:1400
# Ограничения
# 1
#
#
#
# Cвертка: 4.6522343948555926e-08,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 1, 0], '50': [5, 4, 1, 0], '60': [6, 3, 0], '70': [7, 4, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 400, '03': 300, '12': 100, '14': 200, '25': 0, '34': 100, '36': 100, '45': 100, '47': 100, '67': 0}
# v_reseive_to_node: [700, 300, 0, 200, 200, 0, 0, 0]
# v_sent_to_node: [0, 400, 100, 300, 300, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 35.0, 5.0, 25.0, 25.0, 5.0, 5.0, 5.0]
# t_edges: [20.0, 15.0, 5.0, 10.0, 0.0, 5.0, 5.0, 5.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Объемы передаваемой информации / min:1400
# Ограничения
# 1
#
#
#
# Cвертка: 4.6522343948555926e-08,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 3, 0], '50': [5, 2, 1, 0], '60': [6, 3, 0], '70': [7, 6, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 300, '03': 400, '12': 200, '14': 0, '25': 100, '34': 100, '36': 200, '45': 0, '47': 0, '67': 100}
# v_reseive_to_node: [700, 200, 100, 300, 0, 0, 100, 0]
# v_sent_to_node: [0, 300, 200, 400, 100, 100, 200, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 25.0, 15.0, 35.0, 5.0, 5.0, 15.0, 5.0]
# t_edges: [15.0, 20.0, 10.0, 0.0, 5.0, 5.0, 10.0, 0.0, 0.0, 5.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Объемы передаваемой информации / min:1400
# Ограничения
# 1
#
#
#
# Cвертка: 4.6522343948555926e-08,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 3, 0], '50': [5, 2, 1, 0], '60': [6, 3, 0], '70': [7, 6, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 300, '03': 400, '12': 200, '14': 0, '25': 100, '34': 100, '36': 200, '45': 0, '47': 0, '67': 100}
# v_reseive_to_node: [700, 200, 100, 300, 0, 0, 100, 0]
# v_sent_to_node: [0, 300, 200, 400, 100, 100, 200, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 25.0, 15.0, 35.0, 5.0, 5.0, 15.0, 5.0]
# t_edges: [15.0, 20.0, 10.0, 0.0, 5.0, 5.0, 10.0, 0.0, 0.0, 5.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Объемы передаваемой информации / min:1400
# Ограничения
# 1
#
#
#
# Cвертка: 4.6522343948555926e-08,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 1, 0], '50': [5, 4, 3, 0], '60': [6, 3, 0], '70': [7, 6, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 300, '03': 400, '12': 100, '14': 100, '25': 0, '34': 100, '36': 200, '45': 100, '47': 0, '67': 100}
# v_reseive_to_node: [700, 200, 0, 300, 100, 0, 100, 0]
# v_sent_to_node: [0, 300, 100, 400, 200, 100, 200, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 25.0, 5.0, 35.0, 15.0, 5.0, 15.0, 5.0]
# t_edges: [15.0, 20.0, 5.0, 5.0, 0.0, 5.0, 10.0, 5.0, 0.0, 5.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Объемы передаваемой информации / min:1400
# Ограничения
# 1

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')


plt.figure(figsize = (12, 8))
for exp in range(len(experements)):
  plt.plot([i for i in range(len(experements[exp]))], np.log([getattr(experements[exp][i][-1], 'Свертка') for i in range(len(experements[exp]))]), label = str(exp))

plt.xlabel('Поколение')
plt.ylabel('Ln от свертки')
plt.legend()
plt.show()
# Out:
# <ipython-input-34-3d584a83d833>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %%
plt.figure(figsize = (12, 8))
y = np.zeros(len(experements[exp]))
for exp in range(len(experements)):
  y += np.log([getattr(experements[exp][i][-1], 'Свертка') for i in range(len(experements[exp]))])

plt.plot([i for i in range(len(experements[exp]))], y/10)

plt.xlabel('Поколение')
plt.ylabel('Avg Ln от свертки')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
experements[0][-1][-1].draw_result()

# %%
print(experements[0][-1][-1])
# Out:
# Cвертка: 4.6522343948555926e-08,
# Временя выполнение задачи (с): 226.34,
# Хромосома: [6 6 6 6 6 6 6 6]
# Распределение: [0, 1, 2, 3, 4, 5, 6, 7],
# Маршруты передачи данных  задача1задача2:путь: {'10': [1, 0], '20': [2, 1, 0], '30': [3, 0], '40': [4, 1, 0], '50': [5, 2, 1, 0], '60': [6, 3, 0], '70': [7, 4, 3, 0]}
# Нагруженность на узлы: [10, 3500, 3500, 3500, 3500, 3500, 3500, 3500]
# Нагрузка на сеть: {'01': 400, '03': 300, '12': 200, '14': 100, '25': 100, '34': 100, '36': 100, '45': 0, '47': 100, '67': 0}
# v_reseive_to_node: [700, 300, 100, 200, 100, 0, 0, 0]
# v_sent_to_node: [0, 400, 200, 300, 200, 100, 100, 100]
# t_node: [0.006666666666666667, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335, 2.3333333333333335]
# t_send_reseive_data_node: [35.0, 35.0, 15.0, 25.0, 15.0, 5.0, 5.0, 5.0]
# t_edges: [20.0, 15.0, 10.0, 5.0, 5.0, 5.0, 5.0, 0.0, 5.0, 0.0]
#
# Целевые функции (критерии оценки)
# Энергопотребление (МВт) / min:15353.605464839999
# Объемы передаваемой информации / min:1400
# Ограничения
# 1
